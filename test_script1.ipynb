# %%
from Bio import Entrez
import datetime
import csv
Entrez.email = "kevin.esoh@students.jkuat.ac.ke"
api_key = input("Please enter API key (hit enter if you don't have it): ").lower()
currentDate = datetime.date.today()
currentTime = datetime.datetime.now()

def main():
    dataBase = getDataBase()
    searchTerm = getSearchTerm()
    dbSearch(dataBase, searchTerm)
    with open("idList.txt", "r+") as newFile:
        newIdList = csv.reader(newFile)
        for eachID in newIdList:
            idList = ','.join(eachID)
    dbSummary(dataBase, idList)
    return

def getDataBase():
    dataBase = input("Please provide the NCBI database you wish to search: ").lower()
    return dataBase

def getSearchTerm():
    searchTerm = input("Enter you search word(s): ").lower()
    return searchTerm

def dbSearch(dataBase, searchTerm):
    handle = Entrez.esearch(db=dataBase, retmax=30, term=searchTerm, retmode="uid")
    record = Entrez.read(handle)
    #record2 = Entrez.read(handle, validate=True)
    handle.close()
    
    print("Your query: " + record["QueryTranslation"])
    print(" ")
    print("Total count: " + record["Count"] + \
          " Accessed: " + currentDate.strftime('%a %d %B, %Y') + \
          " At: " + currentTime.strftime('%H:%M:%S'))
    idList = record["IdList"]
    print(" ")
    print(idList)
    newList = open("idList.txt", "w+")
    newList.write(',' .join(idList))
    newList.close()
    #print(idList)
    #print(',' .join(idList))
    #print(" ")
    #print(record["Title"])
    return

def dbSummary(dataBase, idList=[]):
    handle = Entrez.esummary(db=dataBase, id=idList, rettype="xml")
    #records = Entrez.read(handle)
    records = Entrez.parse(handle)
    for record in records:
        print(" ")
        #print(record)
        print(record['Id'] + " | " + \
                record['Title'] + " | " + \
                record['AuthorList'][0] + " | " + \
                record['PubDate'])
    handle.close()
    print(" ")
    return
main()
# Out:
# Please provide the NCBI database you wish to search: pubmed
# Enter you search word(s): malaria AND maternal mortality
# Your query: ("malaria"[MeSH Terms] OR "malaria"[All Fields]) AND ("maternal mortality"[MeSH Terms] OR ("maternal"[All Fields] AND "mortality"[All Fields]) OR "maternal mortality"[All Fields])
# Total count: 762 Accessed: Mon 22 April, 2019 At: 19:20:34
# ['30973949', '30871722', '30820319', '30818339', '30798310', '30782707', '30766684', '30723029', '30675851', '30665398', '30642347', '30626380', '30621913', '30621669', '30618462', '30593550', '30574297', '30570795', '30558586', '30551740', '30496107', '30482677', '30474513', '30428880', '30412633', '30400931', '30382868', '30364301', '30351243', '30337594']
#
# 30973949 | The prevalence of histologic acute chorioamnionitis among HIV infected pregnant women in Uganda and its association with adverse birth outcomes. | Ategeka J | 2019
#
# 30871722 | Venezuela's public health crisis: a regional emergency. | Page KR | 2019 Mar 23
#
# 30820319 | "Every Newborn-INDEPTH" (EN-INDEPTH) study protocol for a randomised comparison of household survey modules for measuring stillbirths and neonatal deaths in five Health and Demographic Surveillance sites. | Baschieri A | 2019 Jun
#
# 30818339 | Parasitic infections during pregnancy need not affect infant antibody responses to early vaccination against Streptococcus pneumoniae, diphtheria, or Haemophilus influenzae type B. | McKittrick ND | 2019 Feb
#
# 30798310 | Trends in comparative efficacy and safety of malaria control interventions for maternal and child health outcomes in Africa: a study protocol for a Bayesian network meta-regression exploring the effect of HIV and malaria endemicity spectrum. | Amimo F | 2019 Feb 22
#
# 30782707 | A prospective cohort for the investigation of alteration in temporal transcriptional and microbiome trajectories preceding preterm birth: a study protocol. | Brummaier T | 2019 Jan 15
#
# 30766684 | Drug-related teratogenic and pathologic causes of birth defects in a tertiary hospital in Southwestern Nigeria. | Offor I | 2019 Feb
#
# 30723029 | Intravenous fluid contaminated with Klebsiella oxytoca as a source of sepsis in a preterm newborn: Case report. | Eshetu B | 2019 Feb 2
#
# 30675851 | Modeling the Economic Impact of Substandard and Falsified Antimalarials in the Democratic Republic of the Congo. | Ozawa S | 2019 Jan 21
#
# 30665398 | From high to low malaria transmission in Zanzibar-challenges and opportunities to achieve elimination. | Björkman A | 2019 Jan 22
#
# 30642347 | MiRNA-146a polymorphism increases the odds of malaria in pregnancy. | van Loon W | 2019 Jan 14
#
# 30626380 | Development of an agent-based model to assess the impact of substandard and falsified anti-malarials: Uganda case study. | Ozawa S | 2019 Jan 9
#
# 30621913 | Malaria vaccine trials in pregnant women: An imperative without precedent. | Healy SA | 2019 Feb 4
#
# 30621669 | Maternal health care service utilization in post-war Liberia: analysis of nationally representative cross-sectional household surveys. | Yaya S | 2019 Jan 8
#
# 30618462 | Using the polio programme to deliver primary health care in Nigeria: implementation research. | Bawa S | 2019 Jan 1
#
# 30593550 | Paediatric postdischarge mortality in developing countries: a systematic review. | Nemetchek B | 2018 Dec 28
#
# 30574297 | Intervention heroes of Mozambique from 1997 to 2015: estimates of maternal and child lives saved using the Lives Saved Tool. | Macicame I | 2018 Dec
#
# 30570795 | Community case management of lower chest indrawing pneumonia with oral amoxicillin in children in Kenya. | Onono M | 2018 Dec
#
# 30558586 | Causes of death and predictors of childhood mortality in Rwanda: a matched case-control study using verbal social autopsy. | Gupta N | 2018 Dec 17
#
# 30551740 | Challenging diagnosis of congenital malaria in non-endemic areas. | Romani L | 2018 Dec 14
#
# 30496107 | Measuring progress from 1990 to 2017 and projecting attainment to 2030 of the health-related Sustainable Development Goals for 195 countries and territories: a systematic analysis for the Global Burden of Disease Study 2017. | GBD 2017 SDG Collaborators. | 2018 Nov 10
#
# 30482677 | Health disparities across the counties of Kenya and implications for policy makers, 1990-2016: a systematic analysis for the Global Burden of Disease Study 2016. | Achoki T | 2019 Jan
#
# 30474513 | Cause-specific child mortality performance and contributions to all-cause child mortality, and number of child lives saved during the Millennium Development Goals era: a country-level analysis. | Jin Y | 2018
#
# 30428880 | Impact evaluation of malaria control interventions on morbidity and all-cause child mortality in Mali, 2000-2012. | Kayentao K | 2018 Nov 14
#
# 30412633 | Mapping maternal mortality rate via spatial zero-inflated models for count data: A case study of facility-based maternal deaths from Mozambique. | Loquiha O | 2018
#
# 30400931 | Using equitable impact sensitive tool (EQUIST) to promote implementation of evidence informed policymaking to improve maternal and child health outcomes: a focus on six West African Countries. | Uneke CJ | 2018 Nov 6
#
# 30382868 | Magnitude and factors associated with anemia among pregnant women attending antenatal care in public health centers in central zone of Tigray region, northern Ethiopia: a cross sectional study. | Grum T | 2018 Nov 1
#
# 30364301 | Improving quality of care during childbirth in primary health centres: a stepped-wedge cluster-randomised trial in India. | Agarwal R | 2018
#
# 30351243 | Antimalarial drugs for treating and preventing malaria in pregnant and lactating women. | Saito M | 2018 Nov
#
# 30337594 | Global genetic diversity of var2csa in Plasmodium falciparum with implications for malaria in pregnancy and vaccine development. | Benavente ED | 2018 Oct 18

# %%
Entrez.email = "kevin.esoh@students.jkuat.ac.ke"
api_key = "d1d3e5e1d2195630862f5096c55147210f07"
def main():
    mySep = ","
    idList = getIDs()
    #for eachID in newIdList:
    #    idList = mySep.join(eachID.split())
    #   print(idList)
    searchIDs(idList)
    return

def getIDs():
    with open("idList.txt", "r+") as newFile:
        newIdList = csv.reader(newFile)
        for eachID in newIdList:
            idList = ','.join(eachID)
            print(idList)
    return idList

def searchIDs(idList=[]):
    handle = Entrez.esummary(db=dataBase, id=idList, rettype="xml")
    #handle = Entrez.esummary(db=dataBase, id="30986542,30975198,30894432,30874798,30567031", retmode="xml")
    #for eachId in idList:
    #    handle = Entrez.esummary(db=dataBase, id=eachId, rettype="xml")
    #records = Entrez.read(handle)
    records = Entrez.parse(handle)
    for record in records:
        print(" ")
        #print(record)
        print(record['ArticleIds']['eid'] + " | " + \
              record['Title'] + " | " + \
              record['AuthorList'][0] + " | " + \
              record['DOI'])
        #print(record['Title'])
    handle.close()

    print(" ")
    return
main()

#newFile = open("ncbiFile.txt", "w+")
#newFile.write(records)
#newFile.close()
# Out:
# 30986542,30975198,30894432,30874798,30841892,30823883,30802426,30688212,30638864,30567031
#
# 30986542 | False positive fourth generation HIV test in a patient with severe malaria. | Stempel JM | 10.1016/j.ijid.2019.04.007
#
# 30975198 | Level of knowledge among health care providers on preparation of injectable artesunate for treatment of severe malaria in public health facilities in Tanzania. | Mikomangwa WP | 10.1186/s13104-019-4257-5
#
# 30894432 | Antibodies to Peptides in Semiconserved Domains of RIFINs and STEVORs Correlate with Malaria Exposure. | Zhou AE | 10.1128/mSphere.00097-19
#
# 30874798 | Propensity score analysis of artesunate versus quinine for severe imported Plasmodium falciparum malaria in France. | Elket N | 10.1093/cid/ciz206
#
# 30841892 | What causes severe malaria and its complications in children? Lessons learned over the past 15 years. | Conroy AL | 10.1186/s12916-019-1291-z
#
# 30823883 | Acute interstitial nephritis with podocyte foot-process effacement complicating Plasmodium falciparum infection. | Gleeson PJ | 10.1186/s12936-019-2674-5
#
# 30802426 | Risk factors of severe imported malaria in Anhui province, China. | Zhang T | 10.1016/j.actatropica.2019.02.020
#
# 30688212 | Collider bias and the apparent protective effect of glucose-6-phosphate dehydrogenase deficiency on cerebral malaria. | Watson JA | 10.7554/eLife.43154
#
# 30638864 | The blood transcriptome of childhood malaria. | Boldt ABW | 10.1016/j.ebiom.2018.12.055
#
# 30567031 | [Epidemic situation and diagnosis and treatment of severe falciparum malaria in Nantong City]. | Cai-Qun C | 10.16250/j.32.1374.2017185

# %%
handle = Entrez.esummary(db="pubmed", id="19304878,14630660,30986542,30975198,30894432,30874798,30841892,30823883,30802426,30688212,30638864,30567031", retmode="xml")
records = Entrez.parse(handle)
for record in records:
    # each record is a Python dictionary or list.
    print(record['Title'])

handle.close()
#print(records)
# Out:
# Biopython: freely available Python tools for computational molecular biology and bioinformatics.
# PDB file parser and structure class implemented in Python.
# False positive fourth generation HIV test in a patient with severe malaria.
# Level of knowledge among health care providers on preparation of injectable artesunate for treatment of severe malaria in public health facilities in Tanzania.
# Antibodies to Peptides in Semiconserved Domains of RIFINs and STEVORs Correlate with Malaria Exposure.
# Propensity score analysis of artesunate versus quinine for severe imported Plasmodium falciparum malaria in France.
# What causes severe malaria and its complications in children? Lessons learned over the past 15 years.
# Acute interstitial nephritis with podocyte foot-process effacement complicating Plasmodium falciparum infection.
# Risk factors of severe imported malaria in Anhui province, China.
# Collider bias and the apparent protective effect of glucose-6-phosphate dehydrogenase deficiency on cerebral malaria.
# The blood transcriptome of childhood malaria.
# [Epidemic situation and diagnosis and treatment of severe falciparum malaria in Nantong City].
